# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.loadtxt("energy.txt",delimiter=",")
time = data[:,0]
energy = data[:,1]
energy = energy/energy[0]

plt.plot(time,energy)
plt.show()
